# %% [markdown]
# # 03 — Frontier vs cap-weight (Q2): what does the optimizer want?**Hypothesis H2:** at SPY's current (EWMA) σ, the long-only frontier holds < half the cap weight in M7.**Honesty rule:** μ is the weak joint of MVO. Present three μ scenarios side by side — naive sample means, shrunk, μ-agnostic (min-variance) — and only claim what survives all three.

# %%
import sys; sys.path.append("../src")import numpy as np, pandas as pd, matplotlib.pyplot as pltfrom quiet_index import data, risk, optimize, backtest, plotsplots.use_style()

# %% [markdown]
# ## 1. InputsΣ from NB02 (state which); three μ vectors; current 3-month T-bill rate for the tangency line.

# %% [markdown]
# ## 2. Closed-form frontier (A, B, C, D) + long-only frontierVerify closed-form vs numerical (also unit-tested). Plot both frontiers.

# %%
# TODO(sai): fr = optimize.make_frontier(mu, sigma); ...

# %% [markdown]
# ## 3. Locate the named portfoliosSPY, cap-weight 5-sleeve mix, 60/40, equal-weight, global min-var, tangency — on the σ-μ map.

# %% [markdown]
# ## 4. Target-risk portfolios at two risk budgetsσ = SPY current EWMA vol vs σ = SPY full-sample vol; report M7 allocation each wants → H2 verdict.

# %% [markdown]
# ## 5. Figures & findings- fig: `03_frontier_map` (headline)- fig: `03_allocation_transition` (weights vs target σ)- Verdict on H2, per μ scenario.
