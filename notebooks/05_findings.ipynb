# %% [markdown]
# # 05 — FindingsAssembles the story from NB02-04. Everything here is copy-ready for the README.**Structure:**1. The three questions, one paragraph + one figure each2. Hypothesis scoreboard (H1-H4: confirmed / falsified / mixed — falsified is still a finding)3. So what: what a risk team would DO with this (monitoring additions, limits framing, de-risking options incl. the bills+levered-sleeve variant)4. Limitations (parametric-normal, overlapping windows, proxy sleeves, μ scenarios, no costs; not investment advice)

# %%
import sys; sys.path.append("../src")import numpy as np, pandas as pd, matplotlib.pyplot as pltfrom quiet_index import data, risk, optimize, backtest, plotsplots.use_style()

# %% [markdown]
# ## 1. Export headline figures to figures/ and write the README results table

# %% [markdown]
# ## 2. Hypothesis scoreboard

# %% [markdown]
# ## 3. Narrative (write it here first, then port to README)
